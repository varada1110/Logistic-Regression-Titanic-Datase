# %%
import numpy as np
import pandas as pd
data = pd.read_csv("training_titanicLR.csv",delimiter=",")
data.info()
data
dataset = pd.read_csv("test_titanicLR.csv",delimiter=",")
dataset.info()
dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 668 entries, 0 to 667
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    668 non-null    int64
#  1   Name      668 non-null    object
#  2   Sex       668 non-null    object
#  3   Age       536 non-null    float64
#  4   SibSp     668 non-null    int64
#  5   Parch     668 non-null    int64
#  6   Ticket    668 non-null    object
#  7   Fare      668 non-null    float64
#  8   Cabin     154 non-null    object
#  9   Embarked  667 non-null    object
#  10  Survived  668 non-null    int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 57.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223 entries, 0 to 222
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    223 non-null    int64
#  1   Name      223 non-null    object
# ...

# %%
data.drop(['Sex','Embarked','Name','Ticket','Cabin'],axis=1,inplace=True)
data.head()
# Out:
#    Pclass   Age  SibSp  Parch    Fare  Survived
# 0       2  29.0      1      0  26.000         1
# 1       3   NaN      0      0   8.050         0
# 2       2  39.0      0      0  26.000         0
# 3       3  29.0      0      4  21.075         0
# 4       3  25.0      0      0   7.050         0

# %%
dataset.drop(['Sex','Embarked','Name','Ticket','Cabin'],axis=1,inplace=True)
dataset.head()
# Out:
#    Pclass   Age  SibSp  Parch     Fare
# 0       2   8.0      1      1  36.7500
# 1       1  49.0      0      0  25.9292
# 2       3   NaN      0      0   7.7375
# 3       2  24.0      2      1  27.0000
# 4       1  36.0      0      0  26.2875

# %%
data.isnull().sum()
# Out:
# Pclass        0
# Age         132
# SibSp         0
# Parch         0
# Fare          0
# Survived      0
# dtype: int64

# %%
dataset.isnull().sum()
# Out:
# Pclass     0
# Age       45
# SibSp      0
# Parch      0
# Fare       0
# dtype: int64

# %%
data.Age.fillna(data.Age.mean(),inplace=True)
dataset.Age.fillna(data.Age.mean(),inplace=True)

# %%
data.head()
# Out:
#    Pclass       Age  SibSp  Parch    Fare  Survived
# 0       2  29.00000      1      0  26.000         1
# 1       3  29.70056      0      0   8.050         0
# 2       2  39.00000      0      0  26.000         0
# 3       3  29.00000      0      4  21.075         0
# 4       3  25.00000      0      0   7.050         0

# %%
dataset.head()
# Out:
#    Pclass       Age  SibSp  Parch     Fare
# 0       2   8.00000      1      1  36.7500
# 1       1  49.00000      0      0  25.9292
# 2       3  29.70056      0      0   7.7375
# 3       2  24.00000      2      1  27.0000
# 4       1  36.00000      0      0  26.2875

# %%
x = data.drop("Survived",axis=1)
y = data["Survived"]

# %%
from sklearn import model_selection
X_train,X_test,Y_train,Y_test=model_selection.train_test_split(x,y,random_state=100)

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
clf.score(X_train,Y_train)
# Out:
# 0.6966067864271457

# %%
clf.score(X_test,Y_test)
# Out:
# 0.7065868263473054

# %%
y_pred = clf.predict(dataset)

# %%
y_pred
np.savetxt('titanic_ypred.csv',y_pred,delimiter=",")

# %%
clf.predict_proba(dataset)
# Out:
# array([[0.30933751, 0.69066249],
#        [0.5368265 , 0.4631735 ],
#        [0.76860549, 0.23139451],
#        [0.51680435, 0.48319565],
#        [0.40928002, 0.59071998],
#        [0.69875815, 0.30124185],
#        [0.65657763, 0.34342237],
#        [0.76862176, 0.23137824],
#        [0.67687607, 0.32312393],
#        [0.7673998 , 0.2326002 ],
#        [0.61947734, 0.38052266],
#        [0.76839947, 0.23160053],
#        [0.22174876, 0.77825124],
#        [0.71813664, 0.28186336],
#        [0.72112077, 0.27887923],
#        [0.53980809, 0.46019191],
#        [0.70114703, 0.29885297],
#        [0.51663087, 0.48336913],
#        [0.71070652, 0.28929348],
#        [0.67851392, 0.32148608],
#        [0.77721268, 0.22278732],
#        [0.78430054, 0.21569946],
#        [0.6218529 , 0.3781471 ],
#        [0.34388364, 0.65611636],
#        [0.76923917, 0.23076083],
#        [0.3365449 , 0.6634551 ],
#        [0.56793019, 0.43206981],
#        [0.46265074, 0.53734926],
# ...
